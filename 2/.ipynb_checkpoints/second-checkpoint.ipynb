# %% [markdown]
# # Лабораторная работа №2
# ## Предметная область, источник и характер данных
# Был выбран датасет, который содержит в себе 2000 строк данных о домах с различными характеристиками, которые могут повлиять на цены на жилье. Данные являются реальными - рынки недвижимости, такие как рынки Сиднея и Мельбурна, предоставляют аналитикам данных интересную возможность для анализа и прогнозирования динамики цен на недвижимость. Датасет был взят с сайта https://www.kaggle.com/datasets/zafarali27/house-price-prediction-dataset
# ## Добавление нового атрибута
# Добавим атрибут под названием "средняя площадь комнаты (Avg Room Area)", рассчитываемый по формуле: Area/(Bedrooms+Bathrooms). Выведем нашу таблицу, а затем добавим в нее новый атрибут:

# %%
import numpy as np
import pandas as pd
import scipy
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import figure
# %matplotlib inline

df = pd.read_csv("./house-price.csv")
df.head()
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 1   2  4272         5          4       3       1958  Downtown  Excellent
# 2   3  3592         2          2       3       1938  Downtown       Good
# 3   4   966         4          2       2       1902  Suburban       Fair
# 4   5  4926         1          4       2       1975  Downtown       Fair
#
#   Garage   Price
# 0     No  149919
# 1     No  424998
# 2     No  266746
# 3    Yes  244020
# 4    Yes  636056

# %%
list = []
for i, row in df.iterrows():
    area = row['Area']
    bedrooms = row['Bedrooms']
    bathrooms = row['Bathrooms']
    avgRoomArea = area/(bedrooms+bathrooms)
    list.append(avgRoomArea)

avgRoomArea = pd.Series(list)
df.insert(0, "avgRoomArea", avgRoomArea)

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   avgRoomArea  2000 non-null   float64
#  1   Id           2000 non-null   int64
#  2   Area         2000 non-null   int64
#  3   Bedrooms     2000 non-null   int64
#  4   Bathrooms    2000 non-null   int64
#  5   Floors       2000 non-null   int64
#  6   YearBuilt    2000 non-null   int64
#  7   Location     2000 non-null   object
#  8   Condition    2000 non-null   object
#  9   Garage       2000 non-null   object
#  10  Price        2000 non-null   int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 172.0+ KB
#    avgRoomArea  Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  \
# 0   151.111111   1  1360         5          4       3       1970  Downtown
# 1   474.666667   2  4272         5          4       3       1958  Downtown
# 2   898.000000   3  3592         2          2       3       1938  Downtown
# 3   161.000000   4   966         4          2       2       1902  Suburban
# 4   985.200000   5  4926         1          4       2       1975  Downtown
#
#    Condition Garage   Price
# 0  Excellent     No  149919
# 1  Excellent     No  424998
# 2       Good     No  266746
# 3       Fair    Yes  244020
# 4       Fair    Yes  636056

# %% [markdown]
# Как мы видим, атрибут был добавлен в датасет.

# %% [markdown]
# ## "Причёсывание датасета"
# Удалим ненужные данные, например, текстовые и ID:

# %%
df = df.drop(['Id', 'Location', 'Condition', 'Garage'], axis="columns")
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   avgRoomArea  2000 non-null   float64
#  1   Area         2000 non-null   int64
#  2   Bedrooms     2000 non-null   int64
#  3   Bathrooms    2000 non-null   int64
#  4   Floors       2000 non-null   int64
#  5   YearBuilt    2000 non-null   int64
#  6   Price        2000 non-null   int64
# dtypes: float64(1), int64(6)
# memory usage: 109.5 KB

# %% [markdown]
# Найдем выбросы и удалим их из датасета:

# %%
for col in df.columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers_count = df[(df[col] < lower_bound) | (df[col] > upper_bound)][col].count()
    print(f"Колонка {col} - {outliers_count} выбросов")

df_filtered = df.copy()
for col in df_filtered.columns:
    Q1 = df_filtered[col].quantile(0.25)
    Q3 = df_filtered[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_filtered = df_filtered[(df_filtered[col] >= lower_bound) & (df_filtered[col] <= upper_bound)]

df_filtered.info()
# Out:
# Колонка avgRoomArea - 73 выбросов
# Колонка Area - 0 выбросов
# Колонка Bedrooms - 0 выбросов
# Колонка Bathrooms - 0 выбросов
# Колонка Floors - 0 выбросов
# Колонка YearBuilt - 0 выбросов
# Колонка Price - 0 выбросов
# <class 'pandas.core.frame.DataFrame'>
# Index: 1927 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   avgRoomArea  1927 non-null   float64
#  1   Area         1927 non-null   int64
#  2   Bedrooms     1927 non-null   int64
#  3   Bathrooms    1927 non-null   int64
#  4   Floors       1927 non-null   int64
#  5   YearBuilt    1927 non-null   int64
#  6   Price        1927 non-null   int64
# dtypes: float64(1), int64(6)
# memory usage: 120.4 KB

# %% [markdown]
# ## Построение графиков
# Построим графики зависимости одной переменной от другой:

# %%
sns.pairplot(df_filtered)
plt.show()

# %% [markdown]
# #### avgRoomArea и Area:
#
# Точки выстраиваются в диагональные кластеры, между этими параметрами есть положительная корреляция.
#
# #### Area и Price:
#
# Также наблюдается положительная корреляция, с увеличением площади чаще всего увеличивается и цена.
#
# #### Price и остальные параметры:
#
# На графиках также видно, что цена слегка выше у объектов с большим числом спален и ванных комнат.
#
# ## Применение метода KMeans

# %%
df_filtered.head()
# Out:
#    avgRoomArea  Area  Bedrooms  Bathrooms  Floors  YearBuilt   Price
# 0   151.111111  1360         5          4       3       1970  149919
# 1   474.666667  4272         5          4       3       1958  424998
# 2   898.000000  3592         2          2       3       1938  266746
# 3   161.000000   966         4          2       2       1902  244020
# 4   985.200000  4926         1          4       2       1975  636056

# %% [markdown]
# Сейчас так выглядит наш датасет. Применим к нему метод KMeans

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(df_filtered)
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(scaled_data)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.xlabel('Количество кластеров')
plt.ylabel('WCSS')
plt.show()
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(scaled_data)
df_filtered['Cluster'] = kmeans.labels_

# %% [markdown]
# ## Визуализация кластеров
# Для визуализации выберем две колонки: площадь и цена.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Area', y='Price', hue='Cluster', data=df_filtered, palette='Set1', legend=False)
plt.title('Визуализация кластеров')
plt.show()

# %% [markdown]
# ## Вывод
#
# В данной лабораторной работе мы научились добавлять в датасет новые атрибуты, которые прямо зависят от значений других атрибутов датасета. Затем было определено количество выбросов, после этого выбросы были удалены. В следующем пункте были построены графики зависимости атрибутов друг от друга, а также был произведен визуальный анализ данных графиков. Последним пунктом была совершена кластеризация датасета с помощью метода KMeans и построен график зависимости количества кластеров от WCSS (суммы квадратов расстояний данных до центров их кластеров). Также были визуализированы кластеры по двум параметрам. По последнему графику можно сделать вывод: точки кластеров распределены по всему графику без явно выраженных границ между ними, кластеры пересекаются по всему диапазону площади и цен. Следовательно, цена не растет и не уменьшается явно с увеличением площади. Это говорит нам о том, что на формирование цены влияет не только площадь.
